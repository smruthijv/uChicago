# %%
# Program to analyse Customer dataset
#
# Smruthi Javagal Vasudeva
# 
# For demonstration purposes only

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point

# %%
# Ingesting customer dataset from csv format (Source : Smruthi Sales)
cust_df = pd.read_csv('../data/Customer.csv')

# %%
cust_df.head()
# Out:
#    S No  Outlet Id               Outlet Name Outlet Status  Erp Id  User ID  \
# 0     1     150345  Seetharam medical stores        Active     NaN     2004
# 1     2     150421    shetty medicals Stores        Active     NaN     2004
# 2     3     150480    Sri Seetharam Medicals        Active     NaN     2004
# 3     4     151295          Amrutha Medicals        Active     NaN     2004
# 4     5     151306            Joshi Medicals        Active     NaN     2004
#
#    User Name                                     Outlet Address  \
# 0  M Pradeep                     Opposite KSRTC Bustand NT Road
# 1  M Pradeep     Neela Prastha kasetty Building BH Road shimoga
# 2  M Pradeep  Hanumanthappa Arcade Near Vinayaka Talkes BH R...
# 3  M Pradeep                               Tank mohalla Shimoga
# 4  M Pradeep  Opposite Shimoga Rice mill 9Th cross Bapuji Na...
#
#                Area      Warehouse  ... Business Proof ID Number  \
# ...

# %%
cust_df.replace("NaN",None,inplace=True)

# %%
print(cust_df)
# Out:
#      S No  Outlet Id               Outlet Name Outlet Status  Erp Id  User ID  \
# 0       1     150345  Seetharam medical stores        Active     NaN     2004
# 1       2     150421    shetty medicals Stores        Active     NaN     2004
# 2       3     150480    Sri Seetharam Medicals        Active     NaN     2004
# 3       4     151295          Amrutha Medicals        Active     NaN     2004
# 4       5     151306            Joshi Medicals        Active     NaN     2004
# ..    ...        ...                       ...           ...     ...      ...
# 715   716     484040        Sri yogesh medical        Active     NaN     2983
# 716   717     490338   sumukha provision store        Active     NaN     2983
# 717   718     493295             shoba treders        Active     NaN     2004
# 718   719     496199              SNEHA STORES        Active     NaN     2004
# 719   720     501172            vinayaka store        Active     NaN     2983
#
# ...

# %%
test = cust_df['Business Proof']

# %%
print(test)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 715    NaN
# 716    NaN
# 717    NaN
# 718    NaN
# 719    NaN
# Name: Business Proof, Length: 720, dtype: object

# %%
test.isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 715    True
# 716    True
# 717    True
# 718    True
# 719    True
# Name: Business Proof, Length: 720, dtype: bool

# %%
test.dropna()
# Out:
# 87     FSSAI License
# 230    FSSAI License
# 269    FSSAI License
# 282    FSSAI License
# 394    FSSAI License
# 701              PAN
# Name: Business Proof, dtype: object

# %%
test.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4116\2399656997.py in ?()
# ----> 1 test.dropna(axis=1)
#
# F:\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, inplace, how, ignore_index)
#    5660         """
#    5661         inplace = validate_bool_kwarg(inplace, "inplace")
#    5662         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    5663         # Validate the axis parameter
# ...

# %%
test.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4116\1497134851.py in ?()
# ----> 1 test.drop()
#
# F:\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5081         falcon  speed     320.0
#    5082                 length      0.3
#    5083         dtype: float64
#    5084         """
# -> 5085         return super().drop(
#    5086             labels=labels,
#    5087             axis=axis,
#    5088             index=index,
#
# F:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4537             axes = {"index": index}
#    4538             if self.ndim == 2:
#    4539                 axes["columns"] = columns
#    4540         else:
# -> 4541             raise ValueError(
# ...

# %%
test.dropna()
# Out:
# 87     FSSAI License
# 230    FSSAI License
# 269    FSSAI License
# 282    FSSAI License
# 394    FSSAI License
# 701              PAN
# Name: Business Proof, dtype: object

# %%
test.dropna(ax=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 test.dropna(ax=1)
#
# TypeError: Series.dropna() got an unexpected keyword argument 'ax'

# %%
test.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4116\2399656997.py in ?()
# ----> 1 test.dropna(axis=1)
#
# F:\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, inplace, how, ignore_index)
#    5660         """
#    5661         inplace = validate_bool_kwarg(inplace, "inplace")
#    5662         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    5663         # Validate the axis parameter
# ...

# %%
test = pd.DataFrame(test)

# %%
test.dropna(axis=1, how='all')
# Out:
#     Business Proof
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 715            NaN
# 716            NaN
# 717            NaN
# 718            NaN
# 719            NaN
#
# [720 rows x 1 columns]

# %%
test.fillna("")
# Out:
#     Business Proof
# 0
# 1
# 2
# 3
# 4
# ..             ...
# 715
# 716
# 717
# 718
# 719
#
# [720 rows x 1 columns]

# %%
cust_df[cust_df.duplicated(subset = ["Outlet Name"])]
# Out:
#      S No  Outlet Id                              Outlet Name Outlet Status  \
# 154   155     186284          SRI MANJUNATHA PROVISION STORES        Active
# 217   218     197801        SRI BASAVESHWARA PROVISION STORES        Active
# 260   261     202775  SHRI VEERABHADRASHWEARA PROVISION STORE        Active
# 283   284     203398  SHRI VEERABHADRASHWEARA PROVISION STORE        Active
# 346   347     228865      VEERHABHADRESHWARA PROVISION STORES        Active
# 352   353     232141        SRI BASAVESHWARA PROVISION STORES        Active
# 373   374     235342               KARNATAKA PROVISION STORES        Active
# 394   395     240232                       S L V SUPER MARKET        Active
# 424   425     251209                 SRI BASAVESHWARA TREDERS        Active
# 429   430     251306                 KRISHNA PROVISION STORES        Active
# 436   437     252618            SRI VINAYAKA PROVISION STORES        Active
# ...

# %%
cust_df["Erp Id"].unique()
# Out:
# array([nan])

# %%
D = cust_df.dtypes.to_dict()
print(D)
# Out:
# {'S No': dtype('int64'), 'Outlet Id': dtype('int64'), 'Outlet Name': dtype('O'), 'Outlet Status': dtype('O'), 'Erp Id': dtype('float64'), 'User ID': dtype('int64'), 'User Name': dtype('O'), 'Outlet Address': dtype('O'), 'Area': dtype('O'), 'Warehouse': dtype('O'), 'ZONE': dtype('O'), 'Subzone': dtype('O'), 'Owner Name': dtype('float64'), 'Owner Mobile': dtype('float64'), 'KeyAccount': dtype('bool'), 'Approved': dtype('O'), 'Created On': dtype('O'), 'FSSAI NO': dtype('float64'), 'TAX No': dtype('float64'), 'GST NO': dtype('O'), 'CST NO': dtype('float64'), 'PAN NO': dtype('O'), 'Outlet Type': dtype('O'), 'Beat Id': dtype('O'), 'Beat Name': dtype('O'), 'Latitude': dtype('float64'), 'Longitude': dtype('float64'), 'Phone Number': dtype('int64'), 'Email': dtype('float64'), 'Balance': dtype('int64'), 'City': dtype('O'), 'State': dtype('O'), 'District': dtype('O'), 'PIN': dtype('int64'), 'Code': dtype('float64'), 'Cash/Credit': dtype('O'), 'Credit limit': dtype('int64'), 'Credit days': dtype
# ...

# %%
cust_df[cust_df.duplicated(subset = ['Outlet Name','GST NO','Area'],keep=False)].sort_values(['Outlet Name']).count()
# Out:
# S No                             25
# Outlet Id                        25
# Outlet Name                      25
# Outlet Status                    25
# Erp Id                            0
# User ID                          25
# User Name                        25
# Outlet Address                   25
# Area                             25
# Warehouse                        25
# ZONE                             25
# Subzone                          25
# Owner Name                        0
# Owner Mobile                      0
# KeyAccount                       25
# Approved                         25
# Created On                       25
# FSSAI NO                          0
# TAX No                            0
# GST NO                            2
# CST NO                            0
# PAN NO                            0
# Outlet Type                      25
# Beat Id                          25
# Beat Name                        25
# Latitude                         25
# ...
